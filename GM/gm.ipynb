# %%
# import the necessary packages
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# load the low resolution world map
world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
# Out:
# C:\Users\Niall.Russell\AppData\Local\Temp\ipykernel_9908\2261681313.py:8: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 8
#       5 import geopandas as gpd
#       7 # load the low resolution world map
# ----> 8 world = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
#
# File c:\Users\Niall.Russell\AppData\Local\anaconda3\Lib\site-packages\geopandas\io\file.py:297, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     294     else:
#     295         path_or_bytes = filename
# --> 297     return _read_file_fiona(
# ...

# %%
# initialize an empty figure and add an axis
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot()

# plot a basic map of the world
world.plot(
    ax=ax,
    color="lightgray",
    edgecolor="black",
    alpha=0.5
)

# turn off axis ticks
ax.set_xticks([])
ax.set_yticks([])

# set the plot title
plt.title("Basic Map of World with GeoPandas")
plt.show()

# %%
import plotly.express as px
import pandas as pd


# Import data from GitHub
data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_with_codes.csv')


# Create basic choropleth map
fig = px.choropleth(data, locations='iso_alpha', color='gdpPercap', hover_name='country',
                    projection='natural earth', title='GDP per Capita by Country')
#fig.show()

# %%
data.head(6)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        4

# %%
pwd
# Out:
# 'c:\\Users\\Niall.Russell\\OneDrive - University of Limerick\\git files\\pands-mywork\\GM'

# %%
gm = pd.read_csv("Applications_by_Nationality.csv")

# %%
gm.head(6)
# Out:
#   NATIONALITY  APPLICATIONS  OFFERS  ACCEPTS
# 0    Pakistan           163       0        0
# 1     Nigeria            60       0        0
# 2      Brazil            47       0        0
# 3       India            35       0        0
# 4      Turkey            32       0        0
# 5     Germany            29       0        0

# %%
gm = gm.drop(["OFFERS", "ACCEPTS"], axis = 1)

# %%
gm
# Out:
#                   NATIONALITY  APPLICATIONS
# 0                    Pakistan           163
# 1                     Nigeria            60
# 2                      Brazil            47
# 3                       India            35
# 4                      Turkey            32
# ..                        ...           ...
# 88                     Rwanda             1
# 89                   Slovenia             1
# 90                    Somalia             1
# 91  Taiwan, Province of China             1
# 92                      Yemen             1
#
# [93 rows x 2 columns]

# %%
fig = px.choropleth(gm, locations='iso_alpha', color='APPLICATIONS', hover_name='country',
                    projection='natural earth', title='Applications by Country')

# %%
pd.set_option("display.max_rows", None)

# %%
gm
# Out:
#                                     NATIONALITY  APPLICATIONS
# 0                                      Pakistan           163
# 1                                       Nigeria            60
# 2                                        Brazil            47
# 3                                         India            35
# 4                                        Turkey            32
# 5                                       Germany            29
# 6                                         Ghana            24
# 7                                 United States            22
# 8                                     Indonesia            20
# 9                                         China            19
# 10                                        Kenya            17
# 11                                     Ethiopia            16
# 12                                  Philippines            15
# 13                                   Bangladesh            13
# ...

# %%
import pycountry

input_countries = gm["NATIONALITY"]

countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3

codes = [countries.get(country, "Unknown code") for country in input_countries]

print(codes)  # prints ['AS', 'CA', 'FR']
# Out:
# ['PAK', 'NGA', 'BRA', 'IND', 'Unknown code', 'DEU', 'GHA', 'USA', 'IDN', 'CHN', 'KEN', 'ETH', 'PHL', 'BGD', 'IRN', 'COL', 'GEO', 'MEX', 'ITA', 'LBN', 'MYS', 'VNM', 'AZE', 'CAN', 'RUS', 'ESP', 'UKR', 'ZWE', 'KAZ', 'NPL', 'POL', 'ZAF', 'Unknown code', 'ECU', 'ROU', 'LKA', 'TZA', 'UGA', 'KGZ', 'NLD', 'PER', 'THA', 'TTO', 'Unknown code', 'AFG', 'ARG', 'AUT', 'EGY', 'FRA', 'Unknown code', 'HUN', 'Unknown code', 'ISR', 'MLT', 'MAR', 'PAN', 'PRY', 'PRT', 'SVK', 'SDN', 'SYR', 'TUN', 'ALB', 'DZA', 'ARM', 'Unknown code', 'BIH', 'BDI', 'CMR', 'CHL', 'CRI', 'HRV', 'Unknown code', 'EST', 'GMB', 'GTM', 'ISL', 'JPN', 'JOR', 'LAO', 'Unknown code', 'MDG', 'MWI', 'MUS', 'MMR', 'NAM', 'NIC', 'Unknown code', 'RWA', 'SVN', 'SOM', 'TWN', 'YEM']

# %%
gm["NATIONALITY"] = gm["NATIONALITY"].str.replace("Venezuela", "Venezuela (Bolivarian Republic of)")

# %%
gm["NATIONALITY"] = gm["NATIONALITY"].str.replace("Turkey", "Türkiye")
